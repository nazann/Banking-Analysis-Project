# %%
# !pip install seaborn matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("data/Banking.csv")
df.head()
# Out:
#   Client ID             Name  Age  Location ID Joined Bank   Banking Contact  \
# 0  IND81288    Raymond Mills   24        34324  06-05-2019    Anthony Torres
# 1  IND65833    Julia Spencer   23        42205  10-12-2001  Jonathan Hawkins
# 2  IND47499   Stephen Murray   27         7314  25-01-2010     Anthony Berry
# 3  IND72498   Virginia Garza   40        34594  28-03-2019        Steve Diaz
# 4  IND60181  Melissa Sanders   46        41269  20-07-2012        Shawn Long
#
#   Nationality            Occupation Fee Structure Loyalty Classification  ...  \
# 0    American  Safety Technician IV          High                   Jade  ...
# 1     African   Software Consultant          High                   Jade  ...
# 2    European    Help Desk Operator          High                   Gold  ...
# 3    American          Geologist II           Mid                 Silver  ...
# 4    American   Assistant Professor           Mid               Platinum  ...
#
# ...

# %%
df.shape
# Out:
# (3000, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Client ID                 3000 non-null   object
#  1   Name                      3000 non-null   object
#  2   Age                       3000 non-null   int64
#  3   Location ID               3000 non-null   int64
#  4   Joined Bank               3000 non-null   object
#  5   Banking Contact           3000 non-null   object
#  6   Nationality               3000 non-null   object
#  7   Occupation                3000 non-null   object
#  8   Fee Structure             3000 non-null   object
#  9   Loyalty Classification    3000 non-null   object
#  10  Estimated Income          3000 non-null   float64
#  11  Superannuation Savings    3000 non-null   float64
#  12  Amount of Credit Cards    3000 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age   Location ID  Estimated Income  Superannuation Savings  \
# count  3000.000000   3000.000000       3000.000000             3000.000000
# mean     51.039667  21563.323000     171305.034263            25531.599673
# std      19.854760  12462.273017     111935.808209            16259.950770
# min      17.000000     12.000000      15919.480000             1482.030000
# 25%      34.000000  10803.500000      82906.595000            12513.775000
# 50%      51.000000  21129.500000     142313.480000            22357.355000
# 75%      69.000000  32054.500000     242290.305000            35464.740000
# max      85.000000  43369.000000     522330.260000            75963.900000
#
#        Amount of Credit Cards  Credit Card Balance    Bank Loans  \
# count             3000.000000          3000.000000  3.000000e+03
# mean                 1.463667          3176.206943  5.913862e+05
# std                  0.676387          2497.094709  4.575570e+05
# ...

# %%
bins=[0,100000,300000, float("inf")]
labels=['Low','Medium','High']
df['Income Band']=pd.cut(df['Estimated Income'],bins=bins,labels=labels,right=False)

# %% [markdown]
# ## First Insights ##

# %% [markdown]
# ## univariate analisys

# %%
df['Income Band'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Income Band'>

# %%
cat_cols=df[["Amount of Credit Cards","Properties Owned","BRId" ,"GenderId","IAId","Income Band","Nationality",
             "Risk Weighting","Occupation","Fee Structure","Loyalty Classification"]]

for i,col in enumerate(cat_cols):
    plt.figure(i)
    sns.countplot(data=df,x=col)

# %% [markdown]
# ## Bivariate A.

# %%
for i,col in enumerate(cat_cols):
    plt.figure(i)
    sns.countplot(data=df,x=col,hue='Nationality')

# %%
for i,col in enumerate(cat_cols):
    plt.figure(i)
    sns.countplot(data=df,x=col,hue='Risk Weighting')

# %% [markdown]
# ## Numerical A.

# %%
num_cols=df[["Estimated Income","Superannuation Savings","Credit Card Balance","Bank Loans","Bank Deposits",
             "Checking Accounts","Saving Accounts","Business Lending"]]

# %%
plt.figure(figsize=(15,10))
for i,col in enumerate(num_cols):
    plt.subplot(4,3,i+1)
    sns.histplot(df[col],kde=True)
plt.subplots_adjust(wspace=0.4, hspace=0.4)

plt.show()

# %% [markdown]
# ## CORR heatmaps

# %%
cols=["Estimated Income","Superannuation Savings","Credit Card Balance","Bank Loans","Bank Deposits",
             "Checking Accounts","Saving Accounts","Business Lending","Foreign Currency Account"]
corr_matrix=df[cols].corr()
plt.figure(figsize=(12,12))
sns.heatmap(corr_matrix,annot=True,cmap="crest")
plt.show()

# %% [markdown]
# Strong Correlation Between Bank Deposits and Checking Accounts (r ≈ 0.85)
# -This indicates that checking account balances contribute significantly to the total bank deposits. Customers with higher checking account balances tend to hold larger overall deposits, reflecting the central role of checking accounts in daily financial activities.
#
# High Correlation Between Bank Deposits and Saving Accounts
# -Savings accounts also make up a substantial portion of total deposits. The positive relationship suggests customers maintain substantial funds in savings alongside their checking accounts, reinforcing the idea that total bank deposits aggregate these key account types.
#
# High Correlation Between Bank Deposits and Business Lending
# -The link between deposits and lending highlights that business clients with larger deposit balances often have higher loan amounts. This may reflect the scale of business operations or the depth of banking relationships where deposit and credit products are bundled.
